# %% [markdown]
# # Mushroom DataSet
#
# To check the Mushroom us Edible or Poisonous
#
# Attribute Information: (classes: edible=e, poisonous=p)
#      1. cap-shape:                bell=b,conical=c,convex=x,flat=f,
#                                   knobbed=k,sunken=s
#      2. cap-surface:              fibrous=f,grooves=g,scaly=y,smooth=s
#      3. cap-color:                brown=n,buff=b,cinnamon=c,gray=g,green=r,
#                                   pink=p,purple=u,red=e,white=w,yellow=y
#      4. bruises?:                 bruises=t,no=f
#      5. odor:                     almond=a,anise=l,creosote=c,fishy=y,foul=f,
#                                   musty=m,none=n,pungent=p,spicy=s
#      6. gill-attachment:          attached=a,descending=d,free=f,notched=n
#      7. gill-spacing:             close=c,crowded=w,distant=d
#      8. gill-size:                broad=b,narrow=n
#      9. gill-color:               black=k,brown=n,buff=b,chocolate=h,gray=g,
#                                   green=r,orange=o,pink=p,purple=u,red=e,
#                                   white=w,yellow=y
#     10. stalk-shape:              enlarging=e,tapering=t
#     11. stalk-root:               bulbous=b,club=c,cup=u,equal=e,
#                                   rhizomorphs=z,rooted=r,missing=?
#     12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
#     13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
#     14. stalk-color-above-ring:   brown=n,buff=b,cinnamon=c,gray=g,orange=o,
#                                   pink=p,red=e,white=w,yellow=y
#     15. stalk-color-below-ring:   brown=n,buff=b,cinnamon=c,gray=g,orange=o,
#                                   pink=p,red=e,white=w,yellow=y
#     16. veil-type:                partial=p,universal=u
#     17. veil-color:               brown=n,orange=o,white=w,yellow=y
#     18. ring-number:              none=n,one=o,two=t
#     19. ring-type:                cobwebby=c,evanescent=e,flaring=f,large=l,
#                                   none=n,pendant=p,sheathing=s,zone=z
#     20. spore-print-color:        black=k,brown=n,buff=b,chocolate=h,green=r,
#                                   orange=o,purple=u,white=w,yellow=y
#     21. population:               abundant=a,clustered=c,numerous=n,
#                                   scattered=s,several=v,solitary=y
#     22. habitat:                  grasses=g,leaves=l,meadows=m,paths=p,
#                                   urban=u,waste=w,woods=d
#
#
# Read the .data file of Mushroom.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# -----------------------
# Header is missing in our .csv file. From our Problem statement we can assign the column names.
#
# Check for the NUll values.
#
#
# --------------------------------

# %%
datafrm=pd.read_csv('agaricus-lepiota.DATA')
datafrm.columns=(['class','cap_shape','cap_surface','cap_clr','bruises','odor','gill_attachment','gill_spacing','gill_size','gill_clr','stalk_shape','stalk_root',
'stalk_surface_above_ring','stalk_surface_below_ring','stalk_clr_above_ring','stalk_clr_below_ring','veil_type','veil_clr','ring_number','ring_type',
'spore_print_clr','population','habitat'])

datafrm.head()
# Out:
#   class cap_shape cap_surface cap_clr bruises odor gill_attachment  \
# 0     e         x           s       y       t    a               f
# 1     e         b           s       w       t    l               f
# 2     p         x           y       w       t    p               f
# 3     e         x           s       g       f    n               f
# 4     e         x           y       y       t    a               f
#
#   gill_spacing gill_size gill_clr  ... stalk_surface_below_ring  \
# 0            c         b        k  ...                        s
# 1            c         b        n  ...                        s
# 2            c         n        n  ...                        s
# 3            w         b        k  ...                        s
# 4            c         b        n  ...                        s
#
#   stalk_clr_above_ring stalk_clr_below_ring veil_type veil_clr ring_number  \
# 0                    w                    w         p        w           o
# ...

# %%
datafrm.dtypes
# Out:
# class                       object
# cap_shape                   object
# cap_surface                 object
# cap_clr                     object
# bruises                     object
# odor                        object
# gill_attachment             object
# gill_spacing                object
# gill_size                   object
# gill_clr                    object
# stalk_shape                 object
# stalk_root                  object
# stalk_surface_above_ring    object
# stalk_surface_below_ring    object
# stalk_clr_above_ring        object
# stalk_clr_below_ring        object
# veil_type                   object
# veil_clr                    object
# ring_number                 object
# ring_type                   object
# spore_print_clr             object
# population                  object
# habitat                     object
# dtype: object

# %%
datafrm.isnull().sum()
# Out:
# class                       0
# cap_shape                   0
# cap_surface                 0
# cap_clr                     0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_clr                    0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_clr_above_ring        0
# stalk_clr_below_ring        0
# veil_type                   0
# veil_clr                    0
# ring_number                 0
# ring_type                   0
# spore_print_clr             0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# ---------------------------------------
#
# We  can  see the data is string and Categorical,so we can use LabelEncodder to assign the numeric values to all categorical data
#
# ---------------

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for col in datafrm.columns:
    datafrm[col]=le.fit_transform(datafrm[col])
    
datafrm.head()
# Out:
#    class  cap_shape  cap_surface  cap_clr  bruises  odor  gill_attachment  \
# 0      0          5            2        9        1     0                1
# 1      0          0            2        8        1     3                1
# 2      1          5            3        8        1     6                1
# 3      0          5            2        3        0     5                1
# 4      0          5            3        9        1     0                1
#
#    gill_spacing  gill_size  gill_clr  ...  stalk_surface_below_ring  \
# 0             0          0         4  ...                         2
# 1             0          0         5  ...                         2
# 2             0          1         5  ...                         2
# 3             1          0         4  ...                         2
# 4             0          0         5  ...                         2
#
#    stalk_clr_above_ring  stalk_clr_below_ring  veil_type  veil_clr  \
# ...

# %%
datafrm.shape
# Out:
# (8123, 23)

# %% [markdown]
# -----------
#
# To check Unique values in every columns

# %%
for col in datafrm.columns:
    print('column : ',col)
    print(datafrm[col].unique())
# Out:
# column :  class
# [0 1]
# column :  cap_shape
# [5 0 4 2 3 1]
# column :  cap_surface
# [2 3 0 1]
# column :  cap_clr
# [9 8 3 4 2 5 0 7 1 6]
# column :  bruises
# [1 0]
# column :  odor
# [0 3 6 5 2 1 8 7 4]
# column :  gill_attachment
# [1 0]
# column :  gill_spacing
# [0 1]
# column :  gill_size
# [0 1]
# column :  gill_clr
# [ 4  5  2  7 10  3  9  1  0  8 11  6]
# column :  stalk_shape
# [0 1]
# column :  stalk_root
# [2 3 1 4 0]
# column :  stalk_surface_above_ring
# [2 0 1 3]
# column :  stalk_surface_below_ring
# [2 0 3 1]
# column :  stalk_clr_above_ring
# [7 3 6 4 0 2 5 1 8]
# column :  stalk_clr_below_ring
# [7 6 3 0 4 2 8 5 1]
# column :  veil_type
# [0]
# column :  veil_clr
# [2 0 1 3]
# column :  ring_number
# [1 2 0]
# column :  ring_type
# [4 0 2 1 3]
# column :  spore_print_clr
# [3 2 6 1 7 5 4 8 0]
# column :  population
# [2 3 0 4 5 1]
# column :  habitat
# [1 3 5 0 4 6 2]

# %% [markdown]
# -------------------
# Unique Values for Veil_Type column is 0 only so we can drop this column.
#
# column :  veil_type's Unique value is
#
# [0]
#
#
#
# Axis 1 means columns.
#
# Inplace True means changes will be saved to same dataframe.
#
#
# # Every Columns are having Categoriers so there will no outliers
#
# -------------------------

# %%
datafrm.drop('veil_type',axis=1,inplace=True)

# %%
datafrm.shape
# Out:
# (8123, 22)

# %%
datafrm.describe()
# Out:
#              class    cap_shape  cap_surface      cap_clr      bruises  \
# count  8123.000000  8123.000000  8123.000000  8123.000000  8123.000000
# mean      0.481965     3.347901     1.827650     4.504740     0.415487
# std       0.499705     1.604323     1.229947     2.545972     0.492836
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill_attachment  gill_spacing    gill_size     gill_clr  \
# count  8123.000000      8123.000000   8123.000000  8123.000000  8123.000000
# mean      4.144528         0.974147      0.161517     0.309122     4.810784
# std       2.103758         0.158705      0.368030     0.462160     3.540565
# ...

# %% [markdown]
# -------------------------
#
# Finding the Corelation between all the columns
#
# -----------------------------

# %%
corr=datafrm.corr()
corr
# Out:
#                              class  cap_shape  cap_surface   cap_clr  \
# class                     1.000000   0.052826     0.178440 -0.031361
# cap_shape                 0.052826   1.000000    -0.050475 -0.048181
# cap_surface               0.178440  -0.050475     1.000000 -0.019398
# cap_clr                  -0.031361  -0.048181    -0.019398  1.000000
# bruises                  -0.501758  -0.035530     0.070214 -0.000736
# odor                     -0.093675  -0.022050     0.045220 -0.387119
# gill_attachment           0.129188   0.078850    -0.034183  0.041440
# gill_spacing             -0.348358   0.013253    -0.282302  0.144250
# gill_size                 0.539944   0.053872     0.208103 -0.169452
# gill_clr                 -0.530574  -0.006010    -0.161014  0.084654
# stalk_shape              -0.101888   0.063949    -0.014104 -0.456562
# stalk_root               -0.379688   0.029973    -0.126300  0.321381
# stalk_surface_above_ring -0.334712  -0.030507     0.089081 -0.060822
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ----------------------------------
#
# Character means column wise class (0: Ediable  & 1: Poisonous) to check the relationship between all the columns with Class column
#
# --------------------------

# %%
axisy='class'
for col in datafrm.columns:
    if col != axisy:
        sns.countplot(x=col,hue='class',data=datafrm)
        plt.show()

# %% [markdown]
# -------------------
#
# Now lets seperate our input and output columns menasn X and Y
#
# We can now normalize the data usinf StandardScaler
#
# As the number of columns are 21 I an reducing these no. of columns to 7 using PAC methode
#
#
# -----

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier


x=datafrm.iloc[:,1:]
y=datafrm.iloc[:,0]

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x=scaler.fit_transform(x)
x=pd.DataFrame(data=x)

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=7)
xpca = pca.fit_transform(x)

x = pd.DataFrame(data=xpca)

# %%
x
# Out:
#              0         1         2         3         4         5         6
# 0    -2.282140  0.280155 -1.199637  0.272464 -1.500946 -1.488939  1.088357
# 1    -1.857989 -0.269630 -1.371854  1.056771 -1.810725 -0.876932 -1.765211
# 2    -0.884307 -0.754150 -1.341004  0.370917 -2.109297 -2.110084  1.079955
# 3     0.689231  1.241717 -3.112609  0.814811  1.541691 -0.554175  0.573946
# 4    -2.471299  0.195849 -1.144930  0.253546 -1.660846 -1.728482  0.878007
# ...        ...       ...       ...       ...       ...       ...       ...
# 8118 -2.244524 -0.920163  2.528582  6.453188  2.790234 -1.328390  0.275068
# 8119 -2.538323 -1.674556  4.323703  7.523929  3.979145 -2.176457  1.669967
# 8120 -1.621277 -0.759203  2.733597  6.452334  2.481232 -1.571385 -0.326516
# 8121  3.670668 -1.032629  0.167598 -0.146494 -0.153736 -0.457375 -0.333471
# 8122 -1.574884 -1.230000  2.446942  6.538345  2.725187 -1.176957  1.500174
#
# [8123 rows x 7 columns]

# %% [markdown]
# ----------------------------
#
# Below logic will check the score of every Classifier Algorithms and it will return the best Accurecy Score with Cross_value_Score and Randon_state
#
#
# --------

# %%
model_lst=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]

def trn_tst_split(model,inpt,outpt,rs=0):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=rs)
    model.fit(x_train,y_train)
    model.score(x_train,y_train)
    pred_val=model.predict(x_test)
    return accuracy_score(y_test,pred_val)

# %%
best_rndm_state=[]
model_name=[]
accurecy_score=[]
cross_val_scr=[]
for algo in model_lst:
    d={}
    a=str(algo)  
    a=a.split('(')[0]
    for i in range(0,100):
        scr = trn_tst_split(algo,x,y,i)
        if scr > 0:
            d[i,a]=[scr*100]
        #        if scr > .82:
        #            print (a,'---------',i,'-------',scr)
    random_st = max(d , key=d.get)
    #print ('\nRandom_state with Model :',random_st,' Accurecy Score is :',(d[random_st]),'\n')
    best_rndm_state.append(random_st[0])
    model_name.append(random_st[1])
    accurecy_score.append(d[random_st])
    cvs=cross_val_score(algo,x,y,scoring='accuracy',cv=15)
    #print('Scoreing Methode :', i,' Mean of Corss_val_Score :',max(lst)[0],' & Std. Deviation :',max(lst)[1])
    cross_val_scr.append(cvs.mean()*100)
print ('\n')
print('---------------Details of all Classification Algorithms---------------')
result=pd.DataFrame({'Model': model_name,'Best_Random_State':best_rndm_state,'Accuracy_Score':accurecy_score,'Cross_Val_Score':cross_val_scr})
result
# Out:
# ---------------Details of all Classification Algorithms---------------
#                     Model  Best_Random_State       Accuracy_Score  \
# 0      LogisticRegression                 77  [91.26153846153846]
# 1              GaussianNB                 87  [92.55384615384615]
# 2                     SVC                 40  [99.01538461538462]
# 3  DecisionTreeClassifier                 21  [99.63076923076923]
# 4    KNeighborsClassifier                 21              [100.0]
#
#    Cross_Val_Score
# 0        87.212419
# 1        89.675490
# 2        94.241383
# 3        96.259853
# 4        98.019225

# %% [markdown]
# ---------------
# # Best Score is 100 for  KNeighborsClassifier
#
# So we can validate the model by checking the ROC_AUC Graph and Score
#
# ------------------------

# %%
#---------KNeighborsClassifier--------------------

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=21)
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
pred_val=knn.predict(x_test)

print ('------------KNeighborsClassifier-------------')
print ('Accurecy Score : ',accuracy_score(y_test,pred_val))
print ('Confusion Matrix :',confusion_matrix(y_test,pred_val))
print ('Classification Report :',classification_report(y_test,pred_val))
# Out:
# ------------KNeighborsClassifier-------------
# Accurecy Score :  1.0
# Confusion Matrix : [[849   0]
#  [  0 776]]
# Classification Report :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       849
#            1       1.00      1.00      1.00       776
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
#roc_auc
y_pred_prob=knn.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)
roc_scr=roc_auc_score(y_test,y_pred_prob)
roc_scr
# Out:
# 1.0

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='KNeighborsClassifier')
plt.xlabel=''
plt.ylabel=''
plt.title('K Neighbors Classifier')
plt.show()

# %% [markdown]
# --------------------------------------------------
#
# # Out of 5 Classifier algorithms we are getting 100 % result for KNeighborsClassifier
#
#  so I can finalised my KNeighborsClassifier model
#
#
#
# ----------------------------------------------

# %%
import joblib

joblib.dump(knn,'Mushroom_Classification.plk')
# Out:
# ['Mushroom_Classification.plk']
